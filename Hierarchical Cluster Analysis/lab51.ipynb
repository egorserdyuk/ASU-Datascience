# %%
import pandas as pd

# %%
df = pd.read_csv("beverage_r.csv", sep=";")
# Out:
#     numb.obs  COKE  D_COKE  D_PEPSI  D_7UP  PEPSI  SPRITE  TAB  SEVENUP
# 0          1     1       0        0      0      1       1    0        1
# 1          2     1       0        0      0      1       0    0        0
# 2          3     1       0        0      0      1       0    0        0
# 3          4     0       1        0      1      0       0    1        0
# 4          5     1       0        0      0      1       0    0        0
# 5          6     1       0        0      0      1       1    0        0
# 6          7     0       1        1      1      0       0    1        0
# 7          8     1       1        0      0      1       1    0        1
# 8          9     1       1        0      0      0       1    1        1
# 9         10     1       0        0      0      1       0    0        1
# 10        11     1       0        0      0      1       1    0        0
# 11        12     0       1        0      0      0       0    1        0
# ...
