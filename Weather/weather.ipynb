# %%
import pandas as pd

# %%
df = pd.read_excel("data.xlsx", names=['Индекс ВМО', 'Год', 'Месяц', 'День', 'Минмиальная температура воздуха', 'Средняя температура воздуха', 'Максимальная температура воздуха', 'Количество осадков'])

# %%
df.head()
# Out:
#    Индекс ВМО   Год  Месяц  День  Минмиальная температура воздуха  \
# 0       29838  1959      1     2                            -33.1
# 1       29838  1959      1     3                            -28.8
# 2       29838  1959      1     4                            -25.6
# 3       29838  1959      1     5                            -23.0
# 4       29838  1959      1     6                            -30.6
#
#    Средняя температура воздуха  Максимальная температура воздуха  \
# 0                        -30.0                             -26.2
# 1                        -23.2                             -18.4
# 2                        -22.8                             -18.8
# 3                        -18.4                             -13.0
# 4                        -28.4                             -18.0
#
#    Количество осадков
# 0                 0.0
# 1                 0.0
# 2                 0.0
# 3                 1.3
# 4                 0.4

# %%
df['Дата'] = df['Год'].astype(str) + df['Месяц'].astype(str) + df['День'].astype(str)
df = df.drop('Год', axis=1)
df = df.drop('Месяц', axis=1)
df = df.drop('День', axis=1)

df['Дата'] = pd.to_datetime(df['Дата'], format='%Y%m%d')

# %%
df = df.set_index(df['Дата'])

df.head()
# Out:
#             Минмиальная температура воздуха  Средняя температура воздуха  \
# Дата
# 1959-01-02                            -33.1                        -30.0
# 1959-01-03                            -28.8                        -23.2
# 1959-01-04                            -25.6                        -22.8
# 1959-01-05                            -23.0                        -18.4
# 1959-01-06                            -30.6                        -28.4
#
#             Максимальная температура воздуха  Количество осадков       Дата
# Дата
# 1959-01-02                             -26.2                 0.0 1959-01-02
# 1959-01-03                             -18.4                 0.0 1959-01-03
# 1959-01-04                             -18.8                 0.0 1959-01-04
# 1959-01-05                             -13.0                 1.3 1959-01-05
# 1959-01-06                             -18.0                 0.4 1959-01-06

# %%
df = df.drop('Индекс ВМО', axis=1)

df.head()
# Out:
#    Минмиальная температура воздуха  Средняя температура воздуха  \
# 0                            -33.1                        -30.0
# 1                            -28.8                        -23.2
# 2                            -25.6                        -22.8
# 3                            -23.0                        -18.4
# 4                            -30.6                        -28.4
#
#    Максимальная температура воздуха  Количество осадков       Дата
# 0                             -26.2                 0.0 1959-01-02
# 1                             -18.4                 0.0 1959-01-03
# 2                             -18.8                 0.0 1959-01-04
# 3                             -13.0                 1.3 1959-01-05
# 4                             -18.0                 0.4 1959-01-06

# %%
print('Date lost =' + str(pd.isnull(df['Дата']).sum()))
print('Min lost =' + str(pd.isnull(df['Минмиальная температура воздуха']).sum()))
print('Mean lost =' + str(pd.isnull(df['Средняя температура воздуха']).sum()))
print('Max lost =' + str(pd.isnull(df['Максимальная температура воздуха']).sum()))
print('Value lost =' + str(pd.isnull(df['Количество осадков']).sum()))
# Out:
# Date lost =0
# Min lost =24
# Mean lost =24
# Max lost =25
# Value lost =571

# %%
def nulls(x):
    s = x.isnull().sum().sum(axis=0)
    if s > 0:
        print("year " + s)

# %%
df.groupby(pd.Grouper(freq='Y')).count()

# %%
df
# Out:
#             Минмиальная температура воздуха  Средняя температура воздуха  \
# Дата
# 1959-01-02                            -33.1                        -30.0
# 1959-01-03                            -28.8                        -23.2
# 1959-01-04                            -25.6                        -22.8
# 1959-01-05                            -23.0                        -18.4
# 1959-01-06                            -30.6                        -28.4
# 1959-01-07                            -30.8                        -25.0
# 1959-01-08                            -25.2                        -22.6
# 1959-01-09                            -28.7                        -22.6
# 1959-01-10                            -18.6                        -13.2
# 1959-11-01                            -18.7                        -15.1
# 1959-11-02                            -21.6                        -17.1
# 1959-11-03                            -23.8                        -21.0
# ...

# %%
# date = "196611"
# date = pd.to_datetime(date, format='%Y%m%d')
# for x in df['Дата']:
#     if df['Дата'] < date:
#         df = df.drop('Дата', axis=0)
#         df = df.drop('Минмиальная температура воздуха', axis=0)
#         df = df.drop('Средняя температура воздуха', axis=0)
#         df = df.drop('Максимальная температура воздуха', axis=0)
#         df = df.drop('Количество осадков', axis=0)
        

# df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-4847a4f3eb23> in <module>
#       2 date = pd.to_datetime(date, format='%Y%m%d')
#       3 for x in df['Дата']:
# ----> 4     if df['Дата'] < date:
#       5         df = df.drop('Дата', axis=0)
#       6         df = df.drop('Минмиальная температура воздуха', axis=0)
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
